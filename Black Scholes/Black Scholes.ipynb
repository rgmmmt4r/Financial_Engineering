# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
N = norm.cdf

def BS_CALL(S,K,T,r,sigma):
    d1 = (np.log(S/K) + (r + (sigma**2)/2)*T)/(sigma*np.sqrt(T))
    d2 = d1 - sigma*np.sqrt(T)

    return S*N(d1) - K*np.exp(-r*T)*N(d2)

def BS_PUT(S,K,T,r,sigma):
    d1 = (np.log(S/K) + (r + (sigma**2)/2)*T)/(sigma*np.sqrt(T))
    d2 = d1 - sigma*np.sqrt(T)

    return N(-d2)*K*np.exp(-r*T) - N(-d1)*S

# %%
print(BS_CALL(50,55,1,0.05,0.2))
print(BS_PUT(50,55,1,0.05,0.2))
# Out:
# 3.0200440648621196
# 5.3376624124013965

# %%
K = 100
r = 0.1
T = 1
sigma = 0.3

S = np.arange(30,200,0.1)

calls = [BS_CALL(s,K,r,T,sigma) for s in S]
puts = [BS_PUT(s,K,r,T,sigma) for s in S]

plt.plot(S,calls)
plt.plot(S,puts)
plt.show()

# %%
S = 100
K = 100
r = 0.1
T = 1
Sigmas = np.arange(0.1,1.5,0.01)



calls = [BS_CALL(S,K,r,T,sigma) for sigma in Sigmas]
puts = [BS_PUT(S,K,r,T,sigma) for sigma in Sigmas]

plt.plot(Sigmas,calls)
plt.plot(Sigmas,puts)
plt.show()

# %% [markdown]
# Sigmas increase => option value increase

# %%
S = 100
K = 100
r = 0.000000001
T = 1
Sigmas = np.arange(0.1,1.5,0.01)



calls = [BS_CALL(S,K,r,T,sigma) for sigma in Sigmas]
puts = [BS_PUT(S,K,r,T,sigma) for sigma in Sigmas]

plt.plot(Sigmas,calls)
plt.plot(Sigmas,puts)
plt.show()

# %% [markdown]
# r -> 0 => put call value 重和

# %%
S = 100
K = 100
r = 0.05
Times = np.arange(0,1,0.01)
sigma =  0.3


calls = [BS_CALL(S,K,t,r,sigma) for t in Times]
puts = [BS_PUT(S,K,t,r,sigma) for t in Times]

plt.plot(Times,calls, label='Call Value')
plt.plot(Times,puts, label='Put Value')
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\financial\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
# C:\Users\user\anaconda3\envs\financial\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   del sys.path[0]

# %% [markdown]
# Option with dividend

# %%
N = norm.cdf

def BS_div_CALL(S,K,T,r,q,sigma):
    d1 = (np.log(S/K) + (r -q + (sigma**2)/2)*T)/(sigma*np.sqrt(T))
    d2 = d1 - sigma*np.sqrt(T)

    return S*np.exp(-q*T)*N(d1) - K*np.exp(-r*T)*N(d2)

def BS_div_PUT(S,K,T,r,q,sigma):
    d1 = (np.log(S/K) + (r + (sigma**2)/2)*T)/(sigma*np.sqrt(T))
    d2 = d1 - sigma*np.sqrt(T)

    return N(-d2)*K*np.exp(-r*T) - N(-d1)*S*np.exp(-q*T)

# %%
BS__div_CALL(100,100,1,0.05,0.5,0.3)
# Out:
# 0.6624094369514992

# %%
BS_div_PUT(100,100,1,0.05,0.5,0.3)
# Out:
# 24.138739709551142
